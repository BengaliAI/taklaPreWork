# %%
import pandas as pd
from glob import glob
from utils.graphemeParser import GraphemeParser
import numpy as np
from utils.wordCleaner import WordCleaner

# %%
path = 'unique_words/unique_words_anondoB.xlsx'
df = pd.read_excel(path)

# %%
word_list  = list(df.word.values)

# %%
word_list[:5]
# Out:
# ['অ', 'অঁসম্বল', 'অংক', 'অংশ', 'অংশই']

# %%
path_class_map = 'utils/class_map.csv'
df_map = pd.read_csv(path_class_map, encoding = 'utf-8')
df_root = df_map.groupby('component_type').get_group('grapheme_root')
df_root.set_index('label', inplace = True)
df_root.drop(columns=['component_type'], inplace = True)
df_vd = df_map.groupby('component_type').get_group('vowel_diacritic')
df_vd.set_index('label', inplace = True)
df_vd.drop(columns=['component_type'], inplace = True)
df_cd = df_map.groupby('component_type').get_group('consonant_diacritic')
df_cd.set_index('label', inplace = True)
df_cd.drop(columns=['component_type'], inplace = True)
# Out:
# /home/reasat/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
graphemeparser = GraphemeParser(df_root.values, df_vd.values, df_cd.values)

# %%
wordCleaner = WordCleaner()

# %%
for word in word_list:
    if type(word) is str:
        word = wordCleaner.clean(word)
        graphemes = graphemeparser.word2grapheme(word)
        comps_all = [graphemeparser.grapheme2component(grp) for grp in graphemes]

        grapheme_rec_all = [graphemeparser.comp2grapheme(comp)  for comp in comps_all]

        word_rec = graphemeparser.grapheme2word(grapheme_rec_all)

    #     if True:

        if word != word_rec:
            # print(repr('শ্য়পূ'))

            print('==================================================================')

            print('word: {}, unicodes: {}'.format(word, [uc for uc in word]))
            print('word_reconstructed: {}, unicodes: {}'.format(word_rec,[uc for uc in word_rec]))
            print('extracted graphemes', graphemes)
            for grp in graphemes:
                print('grapheme: {}, unicodes: {}, components: {}'.format(
                    grp,
                    [uc for uc in grp],
                    graphemeparser.grapheme2component(grp)
                ))
    #             break
            # print('reconstructed')
# Out:
# ==================================================================
# word: অগ্, unicodes: ['অ', 'গ', '্']
# word_reconstructed: অ, unicodes: ['অ']
# extracted graphemes ['অ']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# ==================================================================
# word: অজানা্, unicodes: ['অ', 'জ', 'া', 'ন', 'া', '্']
# word_reconstructed: অজানা, unicodes: ['অ', 'জ', 'া', 'ন', 'া']
# extracted graphemes ['অ', 'জা', 'না']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: জা, unicodes: ['জ', 'া'], components: ('জ', 'া', '')
# grapheme: না, unicodes: ['ন', 'া'], components: ('ন', 'া', '')
# ==================================================================
# word: অঞ্, unicodes: ['অ', 'ঞ', '্']
# word_reconstructed: অ, unicodes: ['অ']
# extracted graphemes ['অ']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# ==================================================================
# word: অদ্বৈতম্, unicodes: ['অ', 'দ', '্', 'ব', 'ৈ', 'ত', 'ম', '্']
# word_reconstructed: অদ্বৈত, unicodes: ['অ', 'দ', '্', 'ব', 'ৈ', 'ত']
# extracted graphemes ['অ', 'দ্বৈ', 'ত']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: দ্বৈ, unicodes: ['দ', '্', 'ব', 'ৈ'], components: ('দ্ব', 'ৈ', '')
# grapheme: ত, unicodes: ['ত'], components: ('ত', '', '')
# ==================================================================
# word: অনুগ্র্হ, unicodes: ['অ', 'ন', 'ু', 'গ', '্', 'র', '্', 'হ']
# word_reconstructed: অনুগ্হ্র, unicodes: ['অ', 'ন', 'ু', 'গ', '্', 'হ', '্', 'র']
# extracted graphemes ['অ', 'নু', 'গ্র্হ']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: নু, unicodes: ['ন', 'ু'], components: ('ন', 'ু', '')
# grapheme: গ্র্হ, unicodes: ['গ', '্', 'র', '্', 'হ'], components: ('গ্হ', '', '্র')
# ==================================================================
# word: অন্, unicodes: ['অ', 'ন', '্']
# word_reconstructed: অ, unicodes: ['অ']
# extracted graphemes ['অ']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# ==================================================================
# word: অন্ধ্র্প্রদেশের, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'র', '্', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে', 'র']
# word_reconstructed: অন্ধ্প্রদেশের, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে', 'র']
# extracted graphemes ['অ', 'ন্ধ্র্প্র', 'দে', 'শে', 'র']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: ন্ধ্র্প্র, unicodes: ['ন', '্', 'ধ', '্', 'র', '্', 'প', '্', 'র'], components: ('ন্ধ্প', '', '্র্র')
# grapheme: দে, unicodes: ['দ', 'ে'], components: ('দ', 'ে', '')
# grapheme: শে, unicodes: ['শ', 'ে'], components: ('শ', 'ে', '')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: অন্ধ্র্রপ্রদেশে, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'র', '্', 'র', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে']
# word_reconstructed: অন্ধ্রপ্রদেশে, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'র', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে']
# extracted graphemes ['অ', 'ন্ধ্র্র', 'প্র', 'দে', 'শে']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: ন্ধ্র্র, unicodes: ['ন', '্', 'ধ', '্', 'র', '্', 'র'], components: ('ন্ধ', '', '্র্র')
# grapheme: প্র, unicodes: ['প', '্', 'র'], components: ('প', '', '্র')
# grapheme: দে, unicodes: ['দ', 'ে'], components: ('দ', 'ে', '')
# grapheme: শে, unicodes: ['শ', 'ে'], components: ('শ', 'ে', '')
# ==================================================================
# word: অবাক্, unicodes: ['অ', 'ব', 'া', 'ক', '্']
# word_reconstructed: অবা, unicodes: ['অ', 'ব', 'া']
# extracted graphemes ['অ', 'বা']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: বা, unicodes: ['ব', 'া'], components: ('ব', 'া', '')
# ==================================================================
# word: অভিজিত্, unicodes: ['অ', 'ভ', 'ি', 'জ', 'ি', 'ত', '্']
# word_reconstructed: অভিজি, unicodes: ['অ', 'ভ', 'ি', 'জ', 'ি']
# extracted graphemes ['অ', 'ভি', 'জি']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: ভি, unicodes: ['ভ', 'ি'], components: ('ভ', 'ি', '')
# grapheme: জি, unicodes: ['জ', 'ি'], components: ('জ', 'ি', '')
# ==================================================================
# word: অভিজ্ঞানশকুন্তলম্, unicodes: ['অ', 'ভ', 'ি', 'জ', '্', 'ঞ', 'া', 'ন', 'শ', 'ক', 'ু', 'ন', '্', 'ত', 'ল', 'ম', '্']
# word_reconstructed: অভিজ্ঞানশকুন্তল, unicodes: ['অ', 'ভ', 'ি', 'জ', '্', 'ঞ', 'া', 'ন', 'শ', 'ক', 'ু', 'ন', '্', 'ত', 'ল']
# extracted graphemes ['অ', 'ভি', 'জ্ঞা', 'ন', 'শ', 'কু', 'ন্ত', 'ল']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: ভি, unicodes: ['ভ', 'ি'], components: ('ভ', 'ি', '')
# grapheme: জ্ঞা, unicodes: ['জ', '্', 'ঞ', 'া'], components: ('জ্ঞ', 'া', '')
# grapheme: ন, unicodes: ['ন'], components: ('ন', '', '')
# grapheme: শ, unicodes: ['শ'], components: ('শ', '', '')
# grapheme: কু, unicodes: ['ক', 'ু'], components: ('ক', 'ু', '')
# grapheme: ন্ত, unicodes: ['ন', '্', 'ত'], components: ('ন্ত', '', '')
# grapheme: ল, unicodes: ['ল'], components: ('ল', '', '')
# ==================================================================
# word: অরিজিত্, unicodes: ['অ', 'র', 'ি', 'জ', 'ি', 'ত', '্']
# word_reconstructed: অরিজি, unicodes: ['অ', 'র', 'ি', 'জ', 'ি']
# extracted graphemes ['অ', 'রি', 'জি']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: রি, unicodes: ['র', 'ি'], components: ('র', 'ি', '')
# grapheme: জি, unicodes: ['জ', 'ি'], components: ('জ', 'ি', '')
# /home/reasat/Projects/taklaPreWork/utils/graphemeParser.py:23: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   elif word[i] in list(self.roots) + ['়']:
# ==================================================================
# word: অর্থাত্, unicodes: ['অ', 'র', '্', 'থ', 'া', 'ত', '্']
# word_reconstructed: অর্থা, unicodes: ['অ', 'র', '্', 'থ', 'া']
# extracted graphemes ['অ', 'র্থা']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: র্থা, unicodes: ['র', '্', 'থ', 'া'], components: ('থ', 'া', 'র্')
# ==================================================================
# word: অসুস্থ্, unicodes: ['অ', 'স', 'ু', 'স', '্', 'থ', '্']
# word_reconstructed: অসু, unicodes: ['অ', 'স', 'ু']
# extracted graphemes ['অ', 'সু']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: সু, unicodes: ['স', 'ু'], components: ('স', 'ু', '')
# ==================================================================
# word: অস্ত্, unicodes: ['অ', 'স', '্', 'ত', '্']
# word_reconstructed: অ, unicodes: ['অ']
# extracted graphemes ['অ']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# ==================================================================
# word: অ্যান্, unicodes: ['অ', '্', 'য', 'া', 'ন', '্']
# word_reconstructed: অ্যা, unicodes: ['অ', '্', 'য', 'া']
# extracted graphemes ['অ্যা']
# grapheme: অ্যা, unicodes: ['অ', '্', 'য', 'া'], components: ('অ', 'া', '্য')
# ==================================================================
# word: অ্যারোসেটিকস্, unicodes: ['অ', '্', 'য', 'া', 'র', 'ো', 'স', 'ে', 'ট', 'ি', 'ক', 'স', '্']
# word_reconstructed: অ্যারোসেটিক, unicodes: ['অ', '্', 'য', 'া', 'র', 'ো', 'স', 'ে', 'ট', 'ি', 'ক']
# extracted graphemes ['অ্যা', 'রো', 'সে', 'টি', 'ক']
# grapheme: অ্যা, unicodes: ['অ', '্', 'য', 'া'], components: ('অ', 'া', '্য')
# grapheme: রো, unicodes: ['র', 'ো'], components: ('র', 'ো', '')
# grapheme: সে, unicodes: ['স', 'ে'], components: ('স', 'ে', '')
# grapheme: টি, unicodes: ['ট', 'ি'], components: ('ট', 'ি', '')
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# ==================================================================
# word: আক্, unicodes: ['আ', 'ক', '্']
# word_reconstructed: আ, unicodes: ['আ']
# extracted graphemes ['আ']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# ==================================================================
# word: আত্মসাত্, unicodes: ['আ', 'ত', '্', 'ম', 'স', 'া', 'ত', '্']
# word_reconstructed: আত্মসা, unicodes: ['আ', 'ত', '্', 'ম', 'স', 'া']
# extracted graphemes ['আ', 'ত্ম', 'সা']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# grapheme: ত্ম, unicodes: ['ত', '্', 'ম'], components: ('ত্ম', '', '')
# grapheme: সা, unicodes: ['স', 'া'], components: ('স', 'া', '')
# ==================================================================
# word: আমন্, unicodes: ['আ', 'ম', 'ন', '্']
# word_reconstructed: আম, unicodes: ['আ', 'ম']
# extracted graphemes ['আ', 'ম']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# grapheme: ম, unicodes: ['ম'], components: ('ম', '', '')
# ==================================================================
# word: আর্, unicodes: ['আ', 'র', '্']
# word_reconstructed: আ, unicodes: ['আ']
# extracted graphemes ['আ']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# ==================================================================
# word: আলপস্, unicodes: ['আ', 'ল', 'প', 'স', '্']
# word_reconstructed: আলপ, unicodes: ['আ', 'ল', 'প']
# extracted graphemes ['আ', 'ল', 'প']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# grapheme: ল, unicodes: ['ল'], components: ('ল', '', '')
# grapheme: প, unicodes: ['প'], components: ('প', '', '')
# ==================================================================
# word: আশঙ্, unicodes: ['আ', 'শ', 'ঙ', '্']
# word_reconstructed: আশ, unicodes: ['আ', 'শ']
# extracted graphemes ['আ', 'শ']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# grapheme: শ, unicodes: ['শ'], components: ('শ', '', '')
# ==================================================================
# word: আশিস্, unicodes: ['আ', 'শ', 'ি', 'স', '্']
# word_reconstructed: আশি, unicodes: ['আ', 'শ', 'ি']
# extracted graphemes ['আ', 'শি']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# grapheme: শি, unicodes: ['শ', 'ি'], components: ('শ', 'ি', '')
# ==================================================================
# word: আহ্, unicodes: ['আ', 'হ', '্']
# word_reconstructed: আ, unicodes: ['আ']
# extracted graphemes ['আ']
# grapheme: আ, unicodes: ['আ'], components: ('আ', '', '')
# ==================================================================
# word: ইংল্যান্, unicodes: ['ই', 'ং', 'ল', '্', 'য', 'া', 'ন', '্']
# word_reconstructed: ইংল্যা, unicodes: ['ই', 'ং', 'ল', '্', 'য', 'া']
# extracted graphemes ['ই', 'ং', 'ল্যা']
# grapheme: ই, unicodes: ['ই'], components: ('ই', '', '')
# grapheme: ং, unicodes: ['ং'], components: ('ং', '', '')
# grapheme: ল্যা, unicodes: ['ল', '্', 'য', 'া'], components: ('ল', 'া', '্য')
# ==================================================================
# word: ইনট্রোডাকশন্, unicodes: ['ই', 'ন', 'ট', '্', 'র', 'ো', 'ড', 'া', 'ক', 'শ', 'ন', '্']
# word_reconstructed: ইনট্রোডাকশ, unicodes: ['ই', 'ন', 'ট', '্', 'র', 'ো', 'ড', 'া', 'ক', 'শ']
# extracted graphemes ['ই', 'ন', 'ট্রো', 'ডা', 'ক', 'শ']
# grapheme: ই, unicodes: ['ই'], components: ('ই', '', '')
# grapheme: ন, unicodes: ['ন'], components: ('ন', '', '')
# grapheme: ট্রো, unicodes: ['ট', '্', 'র', 'ো'], components: ('ট', 'ো', '্র')
# grapheme: ডা, unicodes: ['ড', 'া'], components: ('ড', 'া', '')
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: শ, unicodes: ['শ'], components: ('শ', '', '')
# ==================================================================
# word: ইন্দো্, unicodes: ['ই', 'ন', '্', 'দ', 'ো', '্']
# word_reconstructed: ইন্দো, unicodes: ['ই', 'ন', '্', 'দ', 'ো']
# extracted graphemes ['ই', 'ন্দো']
# grapheme: ই, unicodes: ['ই'], components: ('ই', '', '')
# grapheme: ন্দো, unicodes: ['ন', '্', 'দ', 'ো'], components: ('ন্দ', 'ো', '')
# ==================================================================
# word: ইস্, unicodes: ['ই', 'স', '্']
# word_reconstructed: ই, unicodes: ['ই']
# extracted graphemes ['ই']
# grapheme: ই, unicodes: ['ই'], components: ('ই', '', '')
# ==================================================================
# word: ইস্স্, unicodes: ['ই', 'স', '্', 'স', '্']
# word_reconstructed: ই, unicodes: ['ই']
# extracted graphemes ['ই']
# grapheme: ই, unicodes: ['ই'], components: ('ই', '', '')
# ==================================================================
# word: উচিত্, unicodes: ['উ', 'চ', 'ি', 'ত', '্']
# word_reconstructed: উচি, unicodes: ['উ', 'চ', 'ি']
# extracted graphemes ['উ', 'চি']
# grapheme: উ, unicodes: ['উ'], components: ('উ', '', '')
# grapheme: চি, unicodes: ['চ', 'ি'], components: ('চ', 'ি', '')
# ==================================================================
# word: উত্, unicodes: ['উ', 'ত', '্']
# word_reconstructed: উ, unicodes: ['উ']
# extracted graphemes ['উ']
# grapheme: উ, unicodes: ['উ'], components: ('উ', '', '')
# ==================================================================
# word: উত্তপ্ত্, unicodes: ['উ', 'ত', '্', 'ত', 'প', '্', 'ত', '্']
# word_reconstructed: উত্ত, unicodes: ['উ', 'ত', '্', 'ত']
# extracted graphemes ['উ', 'ত্ত']
# grapheme: উ, unicodes: ['উ'], components: ('উ', '', '')
# grapheme: ত্ত, unicodes: ['ত', '্', 'ত'], components: ('ত্ত', '', '')
# ==================================================================
# word: উপস্, unicodes: ['উ', 'প', 'স', '্']
# word_reconstructed: উপ, unicodes: ['উ', 'প']
# extracted graphemes ['উ', 'প']
# grapheme: উ, unicodes: ['উ'], components: ('উ', '', '')
# grapheme: প, unicodes: ['প'], components: ('প', '', '')
# ==================================================================
# word: উফ্, unicodes: ['উ', 'ফ', '্']
# word_reconstructed: উ, unicodes: ['উ']
# extracted graphemes ['উ']
# grapheme: উ, unicodes: ['উ'], components: ('উ', '', '')
# ==================================================================
# word: উফ্ফ্, unicodes: ['উ', 'ফ', '্', 'ফ', '্']
# word_reconstructed: উ, unicodes: ['উ']
# extracted graphemes ['উ']
# grapheme: উ, unicodes: ['উ'], components: ('উ', '', '')
# ==================================================================
# word: ঋক্, unicodes: ['ঋ', 'ক', '্']
# word_reconstructed: ঋ, unicodes: ['ঋ']
# extracted graphemes ['ঋ']
# grapheme: ঋ, unicodes: ['ঋ'], components: ('ঋ', '', '')
# ==================================================================
# word: একদিক্, unicodes: ['এ', 'ক', 'দ', 'ি', 'ক', '্']
# word_reconstructed: একদি, unicodes: ['এ', 'ক', 'দ', 'ি']
# extracted graphemes ['এ', 'ক', 'দি']
# grapheme: এ, unicodes: ['এ'], components: ('এ', '', '')
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: দি, unicodes: ['দ', 'ি'], components: ('দ', 'ি', '')
# ==================================================================
# word: একাগ্, unicodes: ['এ', 'ক', 'া', 'গ', '্']
# word_reconstructed: একা, unicodes: ['এ', 'ক', 'া']
# extracted graphemes ['এ', 'কা']
# grapheme: এ, unicodes: ['এ'], components: ('এ', '', '')
# grapheme: কা, unicodes: ['ক', 'া'], components: ('ক', 'া', '')
# ==================================================================
# word: এক্সপ্লোরেশনস্, unicodes: ['এ', 'ক', '্', 'স', 'প', '্', 'ল', 'ো', 'র', 'ে', 'শ', 'ন', 'স', '্']
# word_reconstructed: এক্সপ্লোরেশন, unicodes: ['এ', 'ক', '্', 'স', 'প', '্', 'ল', 'ো', 'র', 'ে', 'শ', 'ন']
# extracted graphemes ['এ', 'ক্স', 'প্লো', 'রে', 'শ', 'ন']
# grapheme: এ, unicodes: ['এ'], components: ('এ', '', '')
# grapheme: ক্স, unicodes: ['ক', '্', 'স'], components: ('ক্স', '', '')
# grapheme: প্লো, unicodes: ['প', '্', 'ল', 'ো'], components: ('প্ল', 'ো', '')
# grapheme: রে, unicodes: ['র', 'ে'], components: ('র', 'ে', '')
# grapheme: শ, unicodes: ['শ'], components: ('শ', '', '')
# grapheme: ন, unicodes: ['ন'], components: ('ন', '', '')
# ==================================================================
# word: এল্, unicodes: ['এ', 'ল', '্']
# word_reconstructed: এ, unicodes: ['এ']
# extracted graphemes ['এ']
# grapheme: এ, unicodes: ['এ'], components: ('এ', '', '')
# ==================================================================
# word: ওত্, unicodes: ['ও', 'ত', '্']
# word_reconstructed: ও, unicodes: ['ও']
# extracted graphemes ['ও']
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# ==================================================================
# word: ওনস্, unicodes: ['ও', 'ন', 'স', '্']
# word_reconstructed: ওন, unicodes: ['ও', 'ন']
# extracted graphemes ['ও', 'ন']
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# grapheme: ন, unicodes: ['ন'], components: ('ন', '', '')
# ==================================================================
# word: ওফ্, unicodes: ['ও', 'ফ', '্']
# word_reconstructed: ও, unicodes: ['ও']
# extracted graphemes ['ও']
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# ==================================================================
# word: ওয়ানস্, unicodes: ['ও', 'য়', 'া', 'ন', 'স', '্']
# word_reconstructed: ওয়ান, unicodes: ['ও', 'য়', 'া', 'ন']
# extracted graphemes ['ও', 'য়া', 'ন']
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# grapheme: য়া, unicodes: ['য়', 'া'], components: ('য়', 'া', '')
# grapheme: ন, unicodes: ['ন'], components: ('ন', '', '')
# ==================================================================
# word: ওয়হ্, unicodes: ['ও', 'য়', 'হ', '্']
# word_reconstructed: ওয়, unicodes: ['ও', 'য়']
# extracted graphemes ['ও', 'য়']
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# grapheme: য়, unicodes: ['য়'], components: ('য়', '', '')
# ==================================================================
# word: ওরট্, unicodes: ['ও', 'র', 'ট', '্']
# word_reconstructed: ওর, unicodes: ['ও', 'র']
# extracted graphemes ['ও', 'র']
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: ওহ্, unicodes: ['ও', 'হ', '্']
# word_reconstructed: ও, unicodes: ['ও']
# extracted graphemes ['ও']
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# ==================================================================
# word: কক্কক্, unicodes: ['ক', 'ক', '্', 'ক', 'ক', '্']
# word_reconstructed: কক্ক, unicodes: ['ক', 'ক', '্', 'ক']
# extracted graphemes ['ক', 'ক্ক']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: ক্ক, unicodes: ['ক', '্', 'ক'], components: ('ক্ক', '', '')
# ==================================================================
# word: কখন্, unicodes: ['ক', 'খ', 'ন', '্']
# word_reconstructed: কখ, unicodes: ['ক', 'খ']
# extracted graphemes ['ক', 'খ']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: খ, unicodes: ['খ'], components: ('খ', '', '')
# ==================================================================
# word: কদাচিত্, unicodes: ['ক', 'দ', 'া', 'চ', 'ি', 'ত', '্']
# word_reconstructed: কদাচি, unicodes: ['ক', 'দ', 'া', 'চ', 'ি']
# extracted graphemes ['ক', 'দা', 'চি']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: দা, unicodes: ['দ', 'া'], components: ('দ', 'া', '')
# grapheme: চি, unicodes: ['চ', 'ি'], components: ('চ', 'ি', '')
# ==================================================================
# word: কনকসন্নিভম্, unicodes: ['ক', 'ন', 'ক', 'স', 'ন', '্', 'ন', 'ি', 'ভ', 'ম', '্']
# word_reconstructed: কনকসন্নিভ, unicodes: ['ক', 'ন', 'ক', 'স', 'ন', '্', 'ন', 'ি', 'ভ']
# extracted graphemes ['ক', 'ন', 'ক', 'স', 'ন্নি', 'ভ']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: ন, unicodes: ['ন'], components: ('ন', '', '')
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: স, unicodes: ['স'], components: ('স', '', '')
# grapheme: ন্নি, unicodes: ['ন', '্', 'ন', 'ি'], components: ('ন্ন', 'ি', '')
# grapheme: ভ, unicodes: ['ভ'], components: ('ভ', '', '')
# ==================================================================
# word: কন্ট্রোলস্, unicodes: ['ক', 'ন', '্', 'ট', '্', 'র', 'ো', 'ল', 'স', '্']
# word_reconstructed: কন্ট্রোল, unicodes: ['ক', 'ন', '্', 'ট', '্', 'র', 'ো', 'ল']
# extracted graphemes ['ক', 'ন্ট্রো', 'ল']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: ন্ট্রো, unicodes: ['ন', '্', 'ট', '্', 'র', 'ো'], components: ('ন্ট', 'ো', '্র')
# grapheme: ল, unicodes: ['ল'], components: ('ল', '', '')
# ==================================================================
# word: কপাত্, unicodes: ['ক', 'প', 'া', 'ত', '্']
# word_reconstructed: কপা, unicodes: ['ক', 'প', 'া']
# extracted graphemes ['ক', 'পা']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: পা, unicodes: ['প', 'া'], components: ('প', 'া', '')
# ==================================================================
# word: কর্, unicodes: ['ক', 'র', '্']
# word_reconstructed: ক, unicodes: ['ক']
# extracted graphemes ['ক']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# ==================================================================
# word: কাকদ্, unicodes: ['ক', 'া', 'ক', 'দ', '্']
# word_reconstructed: কাক, unicodes: ['ক', 'া', 'ক']
# extracted graphemes ['কা', 'ক']
# grapheme: কা, unicodes: ['ক', 'া'], components: ('ক', 'া', '')
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# ==================================================================
# word: কাপল্, unicodes: ['ক', 'া', 'প', 'ল', '্']
# word_reconstructed: কাপ, unicodes: ['ক', 'া', 'প']
# extracted graphemes ['কা', 'প']
# grapheme: কা, unicodes: ['ক', 'া'], components: ('ক', 'া', '')
# grapheme: প, unicodes: ['প'], components: ('প', '', '')
# ==================================================================
# word: কারাঁটিন্, unicodes: ['ক', 'া', 'র', 'া', 'ঁ', 'ট', 'ি', 'ন', '্']
# word_reconstructed: কারাঁটি, unicodes: ['ক', 'া', 'র', 'া', 'ঁ', 'ট', 'ি']
# extracted graphemes ['কা', 'রাঁ', 'টি']
# grapheme: কা, unicodes: ['ক', 'া'], components: ('ক', 'া', '')
# grapheme: রাঁ, unicodes: ['র', 'া', 'ঁ'], components: ('র', 'া', 'ঁ')
# grapheme: টি, unicodes: ['ট', 'ি'], components: ('ট', 'ি', '')
# ==================================================================
# word: কারাঙ্, unicodes: ['ক', 'া', 'র', 'া', 'ঙ', '্']
# word_reconstructed: কারা, unicodes: ['ক', 'া', 'র', 'া']
# extracted graphemes ['কা', 'রা']
# grapheme: কা, unicodes: ['ক', 'া'], components: ('ক', 'া', '')
# grapheme: রা, unicodes: ['র', 'া'], components: ('র', 'া', '')
# ==================================================================
# word: কার্, unicodes: ['ক', 'া', 'র', '্']
# word_reconstructed: কা, unicodes: ['ক', 'া']
# extracted graphemes ['কা']
# grapheme: কা, unicodes: ['ক', 'া'], components: ('ক', 'া', '')
# ==================================================================
# word: কিন্, unicodes: ['ক', 'ি', 'ন', '্']
# word_reconstructed: কি, unicodes: ['ক', 'ি']
# extracted graphemes ['কি']
# grapheme: কি, unicodes: ['ক', 'ি'], components: ('ক', 'ি', '')
# ==================================================================
# word: কিন্তুক্, unicodes: ['ক', 'ি', 'ন', '্', 'ত', 'ু', 'ক', '্']
# word_reconstructed: কিন্তু, unicodes: ['ক', 'ি', 'ন', '্', 'ত', 'ু']
# extracted graphemes ['কি', 'ন্তু']
# grapheme: কি, unicodes: ['ক', 'ি'], components: ('ক', 'ি', '')
# grapheme: ন্তু, unicodes: ['ন', '্', 'ত', 'ু'], components: ('ন্ত', 'ু', '')
# ==================================================================
# word: কিমাশ্চর্যম্, unicodes: ['ক', 'ি', 'ম', 'া', 'শ', '্', 'চ', 'র', '্', 'য', 'ম', '্']
# word_reconstructed: কিমাশ্চর্য, unicodes: ['ক', 'ি', 'ম', 'া', 'শ', '্', 'চ', 'র', '্', 'য']
# extracted graphemes ['কি', 'মা', 'শ্চ', 'র্য']
# grapheme: কি, unicodes: ['ক', 'ি'], components: ('ক', 'ি', '')
# grapheme: মা, unicodes: ['ম', 'া'], components: ('ম', 'া', '')
# grapheme: শ্চ, unicodes: ['শ', '্', 'চ'], components: ('শ্চ', '', '')
# grapheme: র্য, unicodes: ['র', '্', 'য'], components: ('য', '', 'র্')
# ==================================================================
# word: কিম্, unicodes: ['ক', 'ি', 'ম', '্']
# word_reconstructed: কি, unicodes: ['ক', 'ি']
# extracted graphemes ['কি']
# grapheme: কি, unicodes: ['ক', 'ি'], components: ('ক', 'ি', '')
# ==================================================================
# word: কুন্ড্রম্, unicodes: ['ক', 'ু', 'ন', '্', 'ড', '্', 'র', 'ম', '্']
# word_reconstructed: কুন্ড্র, unicodes: ['ক', 'ু', 'ন', '্', 'ড', '্', 'র']
# extracted graphemes ['কু', 'ন্ড্র']
# grapheme: কু, unicodes: ['ক', 'ু'], components: ('ক', 'ু', '')
# grapheme: ন্ড্র, unicodes: ['ন', '্', 'ড', '্', 'র'], components: ('ন্ড', '', '্র')
# ==================================================================
# word: কুম্, unicodes: ['ক', 'ু', 'ম', '্']
# word_reconstructed: কু, unicodes: ['ক', 'ু']
# extracted graphemes ['কু']
# grapheme: কু, unicodes: ['ক', 'ু'], components: ('ক', 'ু', '')
# ==================================================================
# word: কুয়েলজ্, unicodes: ['ক', 'ু', 'য়', 'ে', 'ল', 'জ', '্']
# word_reconstructed: কুয়েল, unicodes: ['ক', 'ু', 'য়', 'ে', 'ল']
# extracted graphemes ['কু', 'য়ে', 'ল']
# grapheme: কু, unicodes: ['ক', 'ু'], components: ('ক', 'ু', '')
# grapheme: য়ে, unicodes: ['য়', 'ে'], components: ('য়', 'ে', '')
# grapheme: ল, unicodes: ['ল'], components: ('ল', '', '')
# ==================================================================
# word: কৃষ্, unicodes: ['ক', 'ৃ', 'ষ', '্']
# word_reconstructed: কৃ, unicodes: ['ক', 'ৃ']
# extracted graphemes ['কৃ']
# grapheme: কৃ, unicodes: ['ক', 'ৃ'], components: ('ক', 'ৃ', '')
# ==================================================================
# word: কেন্, unicodes: ['ক', 'ে', 'ন', '্']
# word_reconstructed: কে, unicodes: ['ক', 'ে']
# extracted graphemes ['কে']
# grapheme: কে, unicodes: ['ক', 'ে'], components: ('ক', 'ে', '')
# ==================================================================
# word: কেন্দ্, unicodes: ['ক', 'ে', 'ন', '্', 'দ', '্']
# word_reconstructed: কে, unicodes: ['ক', 'ে']
# extracted graphemes ['কে']
# grapheme: কে, unicodes: ['ক', 'ে'], components: ('ক', 'ে', '')
# ==================================================================
# word: কেবল্, unicodes: ['ক', 'ে', 'ব', 'ল', '্']
# word_reconstructed: কেব, unicodes: ['ক', 'ে', 'ব']
# extracted graphemes ['কে', 'ব']
# grapheme: কে, unicodes: ['ক', 'ে'], components: ('ক', 'ে', '')
# grapheme: ব, unicodes: ['ব'], components: ('ব', '', '')
# ==================================================================
# word: কোন্, unicodes: ['ক', 'ো', 'ন', '্']
# word_reconstructed: কো, unicodes: ['ক', 'ো']
# extracted graphemes ['কো']
# grapheme: কো, unicodes: ['ক', 'ো'], components: ('ক', 'ো', '')
# ==================================================================
# word: কোন্, unicodes: ['ক', 'ো', 'ন', '্']
# word_reconstructed: কো, unicodes: ['ক', 'ো']
# extracted graphemes ['কো']
# grapheme: কো, unicodes: ['ক', 'ো'], components: ('ক', 'ো', '')
# ==================================================================
# word: ক্, unicodes: ['ক', '্']
# word_reconstructed: , unicodes: []
# extracted graphemes []
# ==================================================================
# word: ক্যাটস্, unicodes: ['ক', '্', 'য', 'া', 'ট', 'স', '্']
# word_reconstructed: ক্যাট, unicodes: ['ক', '্', 'য', 'া', 'ট']
# extracted graphemes ['ক্যা', 'ট']
# grapheme: ক্যা, unicodes: ['ক', '্', 'য', 'া'], components: ('ক', 'া', '্য')
# grapheme: ট, unicodes: ['ট'], components: ('ট', '', '')
# ==================================================================
# word: ক্যুয়েলজ্, unicodes: ['ক', '্', 'য', 'ু', 'য়', 'ে', 'ল', 'জ', '্']
# word_reconstructed: ক্যুয়েল, unicodes: ['ক', '্', 'য', 'ু', 'য়', 'ে', 'ল']
# extracted graphemes ['ক্যু', 'য়ে', 'ল']
# grapheme: ক্যু, unicodes: ['ক', '্', 'য', 'ু'], components: ('ক', 'ু', '্য')
# grapheme: য়ে, unicodes: ['য়', 'ে'], components: ('য়', 'ে', '')
# grapheme: ল, unicodes: ['ল'], components: ('ল', '', '')
# ==================================================================
# word: ক্ষতিগ্, unicodes: ['ক', '্', 'ষ', 'ত', 'ি', 'গ', '্']
# word_reconstructed: ক্ষতি, unicodes: ['ক', '্', 'ষ', 'ত', 'ি']
# extracted graphemes ['ক্ষ', 'তি']
# grapheme: ক্ষ, unicodes: ['ক', '্', 'ষ'], components: ('ক্ষ', '', '')
# grapheme: তি, unicodes: ['ত', 'ি'], components: ('ত', 'ি', '')
# ==================================================================
# word: ক্ষুব্, unicodes: ['ক', '্', 'ষ', 'ু', 'ব', '্']
# word_reconstructed: ক্ষু, unicodes: ['ক', '্', 'ষ', 'ু']
# extracted graphemes ['ক্ষু']
# grapheme: ক্ষু, unicodes: ['ক', '্', 'ষ', 'ু'], components: ('ক্ষ', 'ু', '')
# ==================================================================
# word: ক্ষেত্, unicodes: ['ক', '্', 'ষ', 'ে', 'ত', '্']
# word_reconstructed: ক্ষে, unicodes: ['ক', '্', 'ষ', 'ে']
# extracted graphemes ['ক্ষে']
# grapheme: ক্ষে, unicodes: ['ক', '্', 'ষ', 'ে'], components: ('ক্ষ', 'ে', '')
# ==================================================================
# word: খচ্মচ্, unicodes: ['খ', 'চ', '্', 'ম', 'চ', '্']
# word_reconstructed: খচ্ম, unicodes: ['খ', 'চ', '্', 'ম']
# extracted graphemes ['খ', 'চ্ম']
# grapheme: খ, unicodes: ['খ'], components: ('খ', '', '')
# grapheme: চ্ম, unicodes: ['চ', '্', 'ম'], components: ('চ্ম', '', '')
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-051b7b482d7d> in <module>
#       3         word = wordCleaner.clean(word)
#       4         graphemes = graphemeparser.word2grapheme(word)
# ----> 5         comps_all = [graphemeparser.grapheme2component(grp) for grp in graphemes]
#       6
#       7         grapheme_rec_all = [graphemeparser.comp2grapheme(comp)  for comp in comps_all]
#
# <ipython-input-21-051b7b482d7d> in <listcomp>(.0)
#       3         word = wordCleaner.clean(word)
#       4         graphemes = graphemeparser.word2grapheme(word)
# ----> 5         comps_all = [graphemeparser.grapheme2component(grp) for grp in graphemes]
#       6
#       7         grapheme_rec_all = [graphemeparser.comp2grapheme(comp)  for comp in comps_all]
#
# ~/Projects/taklaPreWork/utils/graphemeParser.py in grapheme2component(self, grapheme)
#     158                         root+=grapheme[i]+grapheme[i + 1] # deal with consonant conjuncts
#     159                         i += 1
# --> 160             elif grapheme[i] in list(self.roots) +  ['়']: # deal with roots and dot
#     161                 # print('2',grapheme[i], [uc for uc in grapheme[i+1:]])
#     162                 if grapheme[i] == 'র': # ro could be starting of ref
#
# KeyboardInterrupt:
