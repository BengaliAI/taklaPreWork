# %%
import pandas as pd
from glob import glob
from utils.graphemeParser import GraphemeParser
import numpy as np
from utils.clean_word import clean_word

# %%
path = 'unique_words/unique_words_anondoB.xlsx'
df = pd.read_excel(path)

# %%
word_list  = list(df.word.values)

# %%
word_list[:5]
# Out:
# ['অ', 'অঁসম্বল', 'অংক', 'অংশ', 'অংশই']

# %%
path_class_map = 'utils/class_map.csv'
df_map = pd.read_csv(path_class_map, encoding = 'utf-8')
df_root = df_map.groupby('component_type').get_group('grapheme_root')
df_root.set_index('label', inplace = True)
df_root.drop(columns=['component_type'], inplace = True)
df_vd = df_map.groupby('component_type').get_group('vowel_diacritic')
df_vd.set_index('label', inplace = True)
df_vd.drop(columns=['component_type'], inplace = True)
df_cd = df_map.groupby('component_type').get_group('consonant_diacritic')
df_cd.set_index('label', inplace = True)
df_cd.drop(columns=['component_type'], inplace = True)
# Out:
# /home/reasat/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py:4315: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
graphemeparser = GraphemeParser(df_root.values, df_vd.values, df_cd.values)

# %%
for word in word_list:
    if type(word) is str:
        word = clean_word(word)
        graphemes = graphemeparser.word2grapheme(word)
        comps_all = [graphemeparser.grapheme2component(grp) for grp in graphemes]

        grapheme_rec_all = [graphemeparser.comp2grapheme(comp)  for comp in comps_all]

        word_rec = graphemeparser.grapheme2word(grapheme_rec_all)

    #     if True:

        if word != word_rec:
            # print(repr('শ্য়পূ'))

            print('==================================================================')

            print('word: {}, unicodes: {}'.format(word, [uc for uc in word]))
            print('word_reconstructed: {}, unicodes: {}'.format(word_rec,[uc for uc in word_rec]))
            print('extracted graphemes', graphemes)
            for grp in graphemes:
                print('grapheme: {}, unicodes: {}, components: {}'.format(
                    grp,
                    [uc for uc in grp],
                    graphemeparser.grapheme2component(grp)
                ))
    #             break
            # print('reconstructed')
# Out:
# ==================================================================
# word: অনুগ্র্হ, unicodes: ['অ', 'ন', 'ু', 'গ', '্', 'র', '্', 'হ']
# word_reconstructed: অনুগ্হ্র, unicodes: ['অ', 'ন', 'ু', 'গ', '্', 'হ', '্', 'র']
# extracted graphemes ['অ', 'নু', 'গ্র্হ']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: নু, unicodes: ['ন', 'ু'], components: ('ন', 'ু', '')
# grapheme: গ্র্হ, unicodes: ['গ', '্', 'র', '্', 'হ'], components: ('গ্হ', '', '্র')
# ==================================================================
# word: অন্ধ্র্প্রদেশের, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'র', '্', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে', 'র']
# word_reconstructed: অন্ধ্প্রদেশের, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে', 'র']
# extracted graphemes ['অ', 'ন্ধ্র্প্র', 'দে', 'শে', 'র']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: ন্ধ্র্প্র, unicodes: ['ন', '্', 'ধ', '্', 'র', '্', 'প', '্', 'র'], components: ('ন্ধ্প', '', '্র্র')
# grapheme: দে, unicodes: ['দ', 'ে'], components: ('দ', 'ে', '')
# grapheme: শে, unicodes: ['শ', 'ে'], components: ('শ', 'ে', '')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: অন্ধ্র্রপ্রদেশে, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'র', '্', 'র', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে']
# word_reconstructed: অন্ধ্রপ্রদেশে, unicodes: ['অ', 'ন', '্', 'ধ', '্', 'র', 'প', '্', 'র', 'দ', 'ে', 'শ', 'ে']
# extracted graphemes ['অ', 'ন্ধ্র্র', 'প্র', 'দে', 'শে']
# grapheme: অ, unicodes: ['অ'], components: ('অ', '', '')
# grapheme: ন্ধ্র্র, unicodes: ['ন', '্', 'ধ', '্', 'র', '্', 'র'], components: ('ন্ধ', '', '্র্র')
# grapheme: প্র, unicodes: ['প', '্', 'র'], components: ('প', '', '্র')
# grapheme: দে, unicodes: ['দ', 'ে'], components: ('দ', 'ে', '')
# grapheme: শে, unicodes: ['শ', 'ে'], components: ('শ', 'ে', '')
# Out of dictionary symbol encountered:  ঌ
# ==================================================================
# word: ঌঋকাল, unicodes: ['ঌ', 'ঋ', 'ক', 'া', 'ল']
# word_reconstructed: ঋকাল, unicodes: ['ঋ', 'ক', 'া', 'ল']
# extracted graphemes ['ঌঋ', 'কা', 'ল']
# Out of dictionary symbol encountered:  ঌ
# grapheme: ঌঋ, unicodes: ['ঌ', 'ঋ'], components: ('ঋ', '', '')
# grapheme: কা, unicodes: ['ক', 'া'], components: ('ক', 'া', '')
# grapheme: ল, unicodes: ['ল'], components: ('ল', '', '')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: কর্তৄপক্ষও, unicodes: ['ক', 'র', '্', 'ত', 'ৄ', 'প', 'ক', '্', 'ষ', 'ও']
# word_reconstructed: কর্তপক্ষও, unicodes: ['ক', 'র', '্', 'ত', 'প', 'ক', '্', 'ষ', 'ও']
# extracted graphemes ['ক', 'র্ত', 'ৄপ', 'ক্ষ', 'ও']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# grapheme: র্ত, unicodes: ['র', '্', 'ত'], components: ('ত', '', 'র্')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄপ, unicodes: ['ৄ', 'প'], components: ('প', '', '')
# grapheme: ক্ষ, unicodes: ['ক', '্', 'ষ'], components: ('ক্ষ', '', '')
# grapheme: ও, unicodes: ['ও'], components: ('ও', '', '')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: কৄষক, unicodes: ['ক', 'ৄ', 'ষ', 'ক']
# word_reconstructed: কষক, unicodes: ['ক', 'ষ', 'ক']
# extracted graphemes ['ক', 'ৄষ', 'ক']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄষ, unicodes: ['ৄ', 'ষ'], components: ('ষ', '', '')
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: কৄষ্ণনগর, unicodes: ['ক', 'ৄ', 'ষ', '্', 'ণ', 'ন', 'গ', 'র']
# word_reconstructed: কষ্ণনগর, unicodes: ['ক', 'ষ', '্', 'ণ', 'ন', 'গ', 'র']
# extracted graphemes ['ক', 'ৄষ্ণ', 'ন', 'গ', 'র']
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄষ্ণ, unicodes: ['ৄ', 'ষ', '্', 'ণ'], components: ('ষ্ণ', '', '')
# grapheme: ন, unicodes: ['ন'], components: ('ন', '', '')
# grapheme: গ, unicodes: ['গ'], components: ('গ', '', '')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: গুরুত্বপূ্র্ণ, unicodes: ['গ', 'ু', 'র', 'ু', 'ত', '্', 'ব', 'প', 'ূ', '্', 'র', '্', 'ণ']
# word_reconstructed: গুরুত্বপূ্ণ্র, unicodes: ['গ', 'ু', 'র', 'ু', 'ত', '্', 'ব', 'প', 'ূ', '্', 'ণ', '্', 'র']
# extracted graphemes ['গু', 'রু', 'ত্ব', 'পূ', '্র্ণ']
# grapheme: গু, unicodes: ['গ', 'ু'], components: ('গ', 'ু', '')
# grapheme: রু, unicodes: ['র', 'ু'], components: ('র', 'ু', '')
# grapheme: ত্ব, unicodes: ['ত', '্', 'ব'], components: ('ত্ব', '', '')
# grapheme: পূ, unicodes: ['প', 'ূ'], components: ('প', 'ূ', '')
# grapheme: ্র্ণ, unicodes: ['্', 'র', '্', 'ণ'], components: ('্ণ', '', '্র')
# ==================================================================
# word: গ্র্র্র্রাম, unicodes: ['গ', '্', 'র', '্', 'র', '্', 'র', '্', 'র', 'া', 'ম']
# word_reconstructed: গ্রাম, unicodes: ['গ', '্', 'র', 'া', 'ম']
# extracted graphemes ['গ্র্র্র্রা', 'ম']
# grapheme: গ্র্র্র্রা, unicodes: ['গ', '্', 'র', '্', 'র', '্', 'র', '্', 'র', 'া'], components: ('গ', 'া', '্র্র্র্র')
# grapheme: ম, unicodes: ['ম'], components: ('ম', '', '')
# ==================================================================
# word: ঘু্র্ণির, unicodes: ['ঘ', 'ু', '্', 'র', '্', 'ণ', 'ি', 'র']
# word_reconstructed: ঘু্ণ্রির, unicodes: ['ঘ', 'ু', '্', 'ণ', '্', 'র', 'ি', 'র']
# extracted graphemes ['ঘু', '্র্ণি', 'র']
# grapheme: ঘু, unicodes: ['ঘ', 'ু'], components: ('ঘ', 'ু', '')
# grapheme: ্র্ণি, unicodes: ['্', 'র', '্', 'ণ', 'ি'], components: ('্ণ', 'ি', '্র')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: ঘূ্র্ণিঝড়, unicodes: ['ঘ', 'ূ', '্', 'র', '্', 'ণ', 'ি', 'ঝ', 'ড', '়']
# word_reconstructed: ঘূ্ণ্রিঝড়, unicodes: ['ঘ', 'ূ', '্', 'ণ', '্', 'র', 'ি', 'ঝ', 'ড', '়']
# extracted graphemes ['ঘূ', '্র্ণি', 'ঝ', 'ড়']
# grapheme: ঘূ, unicodes: ['ঘ', 'ূ'], components: ('ঘ', 'ূ', '')
# grapheme: ্র্ণি, unicodes: ['্', 'র', '্', 'ণ', 'ি'], components: ('্ণ', 'ি', '্র')
# grapheme: ঝ, unicodes: ['ঝ'], components: ('ঝ', '', '')
# grapheme: ড়, unicodes: ['ড', '়'], components: ('ড়', '', '')
# ==================================================================
# word: দলনেত্র্রীর, unicodes: ['দ', 'ল', 'ন', 'ে', 'ত', '্', 'র', '্', 'র', 'ী', 'র']
# word_reconstructed: দলনেত্রীর, unicodes: ['দ', 'ল', 'ন', 'ে', 'ত', '্', 'র', 'ী', 'র']
# extracted graphemes ['দ', 'ল', 'নে', 'ত্র্রী', 'র']
# grapheme: দ, unicodes: ['দ'], components: ('দ', '', '')
# grapheme: ল, unicodes: ['ল'], components: ('ল', '', '')
# grapheme: নে, unicodes: ['ন', 'ে'], components: ('ন', 'ে', '')
# grapheme: ত্র্রী, unicodes: ['ত', '্', 'র', '্', 'র', 'ী'], components: ('ত', 'ী', '্র্র')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: দুষ্কৄতীরা, unicodes: ['দ', 'ু', 'ষ', '্', 'ক', 'ৄ', 'ত', 'ী', 'র', 'া']
# word_reconstructed: দুষ্কতীরা, unicodes: ['দ', 'ু', 'ষ', '্', 'ক', 'ত', 'ী', 'র', 'া']
# extracted graphemes ['দু', 'ষ্ক', 'ৄতী', 'রা']
# grapheme: দু, unicodes: ['দ', 'ু'], components: ('দ', 'ু', '')
# grapheme: ষ্ক, unicodes: ['ষ', '্', 'ক'], components: ('ষ্ক', '', '')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄতী, unicodes: ['ৄ', 'ত', 'ী'], components: ('ত', 'ী', '')
# grapheme: রা, unicodes: ['র', 'া'], components: ('র', 'া', '')
# ==================================================================
# word: দু্র্ঘটনাটাই, unicodes: ['দ', 'ু', '্', 'র', '্', 'ঘ', 'ট', 'ন', 'া', 'ট', 'া', 'ই']
# word_reconstructed: দু্ঘ্রটনাটাই, unicodes: ['দ', 'ু', '্', 'ঘ', '্', 'র', 'ট', 'ন', 'া', 'ট', 'া', 'ই']
# extracted graphemes ['দু', '্র্ঘ', 'ট', 'না', 'টা', 'ই']
# grapheme: দু, unicodes: ['দ', 'ু'], components: ('দ', 'ু', '')
# grapheme: ্র্ঘ, unicodes: ['্', 'র', '্', 'ঘ'], components: ('্ঘ', '', '্র')
# grapheme: ট, unicodes: ['ট'], components: ('ট', '', '')
# grapheme: না, unicodes: ['ন', 'া'], components: ('ন', 'া', '')
# grapheme: টা, unicodes: ['ট', 'া'], components: ('ট', 'া', '')
# grapheme: ই, unicodes: ['ই'], components: ('ই', '', '')
# Out of dictionary symbol encountered:  ঽ
# ==================================================================
# word: নোঽসি, unicodes: ['ন', 'ো', 'ঽ', 'স', 'ি']
# word_reconstructed: নোসি, unicodes: ['ন', 'ো', 'স', 'ি']
# extracted graphemes ['নো', 'ঽসি']
# grapheme: নো, unicodes: ['ন', 'ো'], components: ('ন', 'ো', '')
# Out of dictionary symbol encountered:  ঽ
# grapheme: ঽসি, unicodes: ['ঽ', 'স', 'ি'], components: ('স', 'ি', '')
# ==================================================================
# word: পারিপা্র্শ্বিক, unicodes: ['প', 'া', 'র', 'ি', 'প', 'া', '্', 'র', '্', 'শ', '্', 'ব', 'ি', 'ক']
# word_reconstructed: পারিপা্শ্ব্রিক, unicodes: ['প', 'া', 'র', 'ি', 'প', 'া', '্', 'শ', '্', 'ব', '্', 'র', 'ি', 'ক']
# extracted graphemes ['পা', 'রি', 'পা', '্র্শ্বি', 'ক']
# grapheme: পা, unicodes: ['প', 'া'], components: ('প', 'া', '')
# grapheme: রি, unicodes: ['র', 'ি'], components: ('র', 'ি', '')
# grapheme: পা, unicodes: ['প', 'া'], components: ('প', 'া', '')
# grapheme: ্র্শ্বি, unicodes: ['্', 'র', '্', 'শ', '্', 'ব', 'ি'], components: ('্শ্ব', 'ি', '্র')
# grapheme: ক, unicodes: ['ক'], components: ('ক', '', '')
# ==================================================================
# word: পূ্র্ণ, unicodes: ['প', 'ূ', '্', 'র', '্', 'ণ']
# word_reconstructed: পূ্ণ্র, unicodes: ['প', 'ূ', '্', 'ণ', '্', 'র']
# extracted graphemes ['পূ', '্র্ণ']
# grapheme: পূ, unicodes: ['প', 'ূ'], components: ('প', 'ূ', '')
# grapheme: ্র্ণ, unicodes: ['্', 'র', '্', 'ণ'], components: ('্ণ', '', '্র')
# ==================================================================
# word: পূ্র্বাভাস, unicodes: ['প', 'ূ', '্', 'র', '্', 'ব', 'া', 'ভ', 'া', 'স']
# word_reconstructed: পূ্ব্রাভাস, unicodes: ['প', 'ূ', '্', 'ব', '্', 'র', 'া', 'ভ', 'া', 'স']
# extracted graphemes ['পূ', '্র্বা', 'ভা', 'স']
# grapheme: পূ, unicodes: ['প', 'ূ'], components: ('প', 'ূ', '')
# grapheme: ্র্বা, unicodes: ['্', 'র', '্', 'ব', 'া'], components: ('্ব', 'া', '্র')
# grapheme: ভা, unicodes: ['ভ', 'া'], components: ('ভ', 'া', '')
# grapheme: স, unicodes: ['স'], components: ('স', '', '')
# ==================================================================
# word: প্র্রার্থীদের, unicodes: ['প', '্', 'র', '্', 'র', 'া', 'র', '্', 'থ', 'ী', 'দ', 'ে', 'র']
# word_reconstructed: প্রার্থীদের, unicodes: ['প', '্', 'র', 'া', 'র', '্', 'থ', 'ী', 'দ', 'ে', 'র']
# extracted graphemes ['প্র্রা', 'র্থী', 'দে', 'র']
# grapheme: প্র্রা, unicodes: ['প', '্', 'র', '্', 'র', 'া'], components: ('প', 'া', '্র্র')
# grapheme: র্থী, unicodes: ['র', '্', 'থ', 'ী'], components: ('থ', 'ী', 'র্')
# grapheme: দে, unicodes: ['দ', 'ে'], components: ('দ', 'ে', '')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: প্র্রেমের, unicodes: ['প', '্', 'র', '্', 'র', 'ে', 'ম', 'ে', 'র']
# word_reconstructed: প্রেমের, unicodes: ['প', '্', 'র', 'ে', 'ম', 'ে', 'র']
# extracted graphemes ['প্র্রে', 'মে', 'র']
# grapheme: প্র্রে, unicodes: ['প', '্', 'র', '্', 'র', 'ে'], components: ('প', 'ে', '্র্র')
# grapheme: মে, unicodes: ['ম', 'ে'], components: ('ম', 'ে', '')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: প্র্স্তাব, unicodes: ['প', '্', 'র', '্', 'স', '্', 'ত', 'া', 'ব']
# word_reconstructed: প্স্ত্রাব, unicodes: ['প', '্', 'স', '্', 'ত', '্', 'র', 'া', 'ব']
# extracted graphemes ['প্র্স্তা', 'ব']
# grapheme: প্র্স্তা, unicodes: ['প', '্', 'র', '্', 'স', '্', 'ত', 'া'], components: ('প্স্ত', 'া', '্র')
# grapheme: ব, unicodes: ['ব'], components: ('ব', '', '')
# ==================================================================
# word: বস্ত্র্র, unicodes: ['ব', 'স', '্', 'ত', '্', 'র', '্', 'র']
# word_reconstructed: বস্ত্র, unicodes: ['ব', 'স', '্', 'ত', '্', 'র']
# extracted graphemes ['ব', 'স্ত্র্র']
# grapheme: ব, unicodes: ['ব'], components: ('ব', '', '')
# grapheme: স্ত্র্র, unicodes: ['স', '্', 'ত', '্', 'র', '্', 'র'], components: ('স্ত', '', '্র্র')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: বিবৄতিতে, unicodes: ['ব', 'ি', 'ব', 'ৄ', 'ত', 'ি', 'ত', 'ে']
# word_reconstructed: বিবতিতে, unicodes: ['ব', 'ি', 'ব', 'ত', 'ি', 'ত', 'ে']
# extracted graphemes ['বি', 'ব', 'ৄতি', 'তে']
# grapheme: বি, unicodes: ['ব', 'ি'], components: ('ব', 'ি', '')
# grapheme: ব, unicodes: ['ব'], components: ('ব', '', '')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄতি, unicodes: ['ৄ', 'ত', 'ি'], components: ('ত', 'ি', '')
# grapheme: তে, unicodes: ['ত', 'ে'], components: ('ত', 'ে', '')
# ==================================================================
# word: বুর্বোঁ, unicodes: ['ব', 'ু', 'র', '্', 'ব', 'ো', 'ঁ']
# word_reconstructed: বুবোঁ, unicodes: ['ব', 'ু', 'ব', 'ো', 'ঁ']
# extracted graphemes ['বু', 'র্বোঁ']
# grapheme: বু, unicodes: ['ব', 'ু'], components: ('ব', 'ু', '')
# grapheme: র্বোঁ, unicodes: ['র', '্', 'ব', 'ো', 'ঁ'], components: ('ব', 'ো', 'র্ঁ')
# ==================================================================
# word: বুর্বোঁজ়, unicodes: ['ব', 'ু', 'র', '্', 'ব', 'ো', 'ঁ', 'জ', '়']
# word_reconstructed: বুবোঁজ়, unicodes: ['ব', 'ু', 'ব', 'ো', 'ঁ', 'জ', '়']
# extracted graphemes ['বু', 'র্বোঁ', 'জ়']
# grapheme: বু, unicodes: ['ব', 'ু'], components: ('ব', 'ু', '')
# grapheme: র্বোঁ, unicodes: ['র', '্', 'ব', 'ো', 'ঁ'], components: ('ব', 'ো', 'র্ঁ')
# grapheme: জ়, unicodes: ['জ', '়'], components: ('জ়', '', '')
# ==================================================================
# word: বুর্বোঁর, unicodes: ['ব', 'ু', 'র', '্', 'ব', 'ো', 'ঁ', 'র']
# word_reconstructed: বুবোঁর, unicodes: ['ব', 'ু', 'ব', 'ো', 'ঁ', 'র']
# extracted graphemes ['বু', 'র্বোঁ', 'র']
# grapheme: বু, unicodes: ['ব', 'ু'], components: ('ব', 'ু', '')
# grapheme: র্বোঁ, unicodes: ['র', '্', 'ব', 'ো', 'ঁ'], components: ('ব', 'ো', 'র্ঁ')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: বৄদ্ধি, unicodes: ['ব', 'ৄ', 'দ', '্', 'ধ', 'ি']
# word_reconstructed: বদ্ধি, unicodes: ['ব', 'দ', '্', 'ধ', 'ি']
# extracted graphemes ['ব', 'ৄদ্ধি']
# grapheme: ব, unicodes: ['ব'], components: ('ব', '', '')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄদ্ধি, unicodes: ['ৄ', 'দ', '্', 'ধ', 'ি'], components: ('দ্ধ', 'ি', '')
# ==================================================================
# word: মধ্য়ে, unicodes: ['ম', 'ধ', '্', 'য', '়', 'ে']
# word_reconstructed: মধ়্যে, unicodes: ['ম', 'ধ', '়', '্', 'য', 'ে']
# extracted graphemes ['ম', 'ধ্য়ে']
# grapheme: ম, unicodes: ['ম'], components: ('ম', '', '')
# grapheme: ধ্য়ে, unicodes: ['ধ', '্', 'য', '়', 'ে'], components: ('ধ়', 'ে', '্য')
# ==================================================================
# word: মুহূ্র্তে, unicodes: ['ম', 'ু', 'হ', 'ূ', '্', 'র', '্', 'ত', 'ে']
# word_reconstructed: মুহূ্ত্রে, unicodes: ['ম', 'ু', 'হ', 'ূ', '্', 'ত', '্', 'র', 'ে']
# extracted graphemes ['মু', 'হূ', '্র্তে']
# grapheme: মু, unicodes: ['ম', 'ু'], components: ('ম', 'ু', '')
# grapheme: হূ, unicodes: ['হ', 'ূ'], components: ('হ', 'ূ', '')
# grapheme: ্র্তে, unicodes: ['্', 'র', '্', 'ত', 'ে'], components: ('্ত', 'ে', '্র')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: মৄত্যু, unicodes: ['ম', 'ৄ', 'ত', '্', 'য', 'ু']
# word_reconstructed: মত্যু, unicodes: ['ম', 'ত', '্', 'য', 'ু']
# extracted graphemes ['ম', 'ৄত্যু']
# grapheme: ম, unicodes: ['ম'], components: ('ম', '', '')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄত্যু, unicodes: ['ৄ', 'ত', '্', 'য', 'ু'], components: ('ত', 'ু', '্য')
# Out of dictionary symbol encountered:  ৄ
# ==================================================================
# word: মৄত্যুদণ্ডের, unicodes: ['ম', 'ৄ', 'ত', '্', 'য', 'ু', 'দ', 'ণ', '্', 'ড', 'ে', 'র']
# word_reconstructed: মত্যুদণ্ডের, unicodes: ['ম', 'ত', '্', 'য', 'ু', 'দ', 'ণ', '্', 'ড', 'ে', 'র']
# extracted graphemes ['ম', 'ৄত্যু', 'দ', 'ণ্ডে', 'র']
# grapheme: ম, unicodes: ['ম'], components: ('ম', '', '')
# Out of dictionary symbol encountered:  ৄ
# grapheme: ৄত্যু, unicodes: ['ৄ', 'ত', '্', 'য', 'ু'], components: ('ত', 'ু', '্য')
# grapheme: দ, unicodes: ['দ'], components: ('দ', '', '')
# grapheme: ণ্ডে, unicodes: ['ণ', '্', 'ড', 'ে'], components: ('ণ্ড', 'ে', '')
# grapheme: র, unicodes: ['র'], components: ('র', '', '')
# ==================================================================
# word: রিজা্র্ভ, unicodes: ['র', 'ি', 'জ', 'া', '্', 'র', '্', 'ভ']
# word_reconstructed: রিজা্ভ্র, unicodes: ['র', 'ি', 'জ', 'া', '্', 'ভ', '্', 'র']
# extracted graphemes ['রি', 'জা', '্র্ভ']
# grapheme: রি, unicodes: ['র', 'ি'], components: ('র', 'ি', '')
# grapheme: জা, unicodes: ['জ', 'া'], components: ('জ', 'া', '')
# grapheme: ্র্ভ, unicodes: ['্', 'র', '্', 'ভ'], components: ('্ভ', '', '্র')
# ==================================================================
# word: র্যাঁবো, unicodes: ['র', '্', 'য', 'া', 'ঁ', 'ব', 'ো']
# word_reconstructed: যাঁবো, unicodes: ['য', 'া', 'ঁ', 'ব', 'ো']
# extracted graphemes ['র্যাঁ', 'বো']
# grapheme: র্যাঁ, unicodes: ['র', '্', 'য', 'া', 'ঁ'], components: ('য', 'া', 'র্ঁ')
# grapheme: বো, unicodes: ['ব', 'ো'], components: ('ব', 'ো', '')
# Out of dictionary symbol encountered:  ঽ
# ==================================================================
# word: শাশ্বতোঽয়ং, unicodes: ['শ', 'া', 'শ', '্', 'ব', 'ত', 'ো', 'ঽ', 'য়', 'ং']
# word_reconstructed: শাশ্বতোয়ং, unicodes: ['শ', 'া', 'শ', '্', 'ব', 'ত', 'ো', 'য়', 'ং']
# extracted graphemes ['শা', 'শ্ব', 'তো', 'ঽয়', 'ং']
# grapheme: শা, unicodes: ['শ', 'া'], components: ('শ', 'া', '')
# grapheme: শ্ব, unicodes: ['শ', '্', 'ব'], components: ('শ্ব', '', '')
# grapheme: তো, unicodes: ['ত', 'ো'], components: ('ত', 'ো', '')
# Out of dictionary symbol encountered:  ঽ
# grapheme: ঽয়, unicodes: ['ঽ', 'য়'], components: ('য়', '', '')
# grapheme: ং, unicodes: ['ং'], components: ('ং', '', '')
# ==================================================================
# word: শ্র্দ্ধায়, unicodes: ['শ', '্', 'র', '্', 'দ', '্', 'ধ', 'া', 'য়']
# word_reconstructed: শ্দ্ধ্রায়, unicodes: ['শ', '্', 'দ', '্', 'ধ', '্', 'র', 'া', 'য়']
# extracted graphemes ['শ্র্দ্ধা', 'য়']
# grapheme: শ্র্দ্ধা, unicodes: ['শ', '্', 'র', '্', 'দ', '্', 'ধ', 'া'], components: ('শ্দ্ধ', 'া', '্র')
# grapheme: য়, unicodes: ['য়'], components: ('য়', '', '')
# ==================================================================
# word: সদ্যপ্র্য়াত, unicodes: ['স', 'দ', '্', 'য', 'প', '্', 'র', '্', 'য়', 'া', 'ত']
# word_reconstructed: সদ্যপ্য়্রাত, unicodes: ['স', 'দ', '্', 'য', 'প', '্', 'য়', '্', 'র', 'া', 'ত']
# extracted graphemes ['স', 'দ্য', 'প্র্য়া', 'ত']
# grapheme: স, unicodes: ['স'], components: ('স', '', '')
# grapheme: দ্য, unicodes: ['দ', '্', 'য'], components: ('দ', '', '্য')
# grapheme: প্র্য়া, unicodes: ['প', '্', 'র', '্', 'য়', 'া'], components: ('প্য়', 'া', '্র')
# grapheme: ত, unicodes: ['ত'], components: ('ত', '', '')
# ==================================================================
# word: সম্পূ্র্ণ, unicodes: ['স', 'ম', '্', 'প', 'ূ', '্', 'র', '্', 'ণ']
# word_reconstructed: সম্পূ্ণ্র, unicodes: ['স', 'ম', '্', 'প', 'ূ', '্', 'ণ', '্', 'র']
# extracted graphemes ['স', 'ম্পূ', '্র্ণ']
# grapheme: স, unicodes: ['স'], components: ('স', '', '')
# grapheme: ম্পূ, unicodes: ['ম', '্', 'প', 'ূ'], components: ('ম্প', 'ূ', '')
# grapheme: ্র্ণ, unicodes: ['্', 'র', '্', 'ণ'], components: ('্ণ', '', '্র')
# ==================================================================
# word: ্য্য, unicodes: ['্', 'য', '্', 'য']
# word_reconstructed: ্য, unicodes: ['্', 'য']
# extracted graphemes ['্য্য']
# grapheme: ্য্য, unicodes: ['্', 'য', '্', 'য'], components: ('', '', '্য্য')
